# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Wholesale customers data.csv")
df
# Out:
#      Channel  Region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  \
# 0          2       3  12669   9656     7561     214              2674
# 1          2       3   7057   9810     9568    1762              3293
# 2          2       3   6353   8808     7684    2405              3516
# 3          1       3  13265   1196     4221    6404               507
# 4          2       3  22615   5410     7198    3915              1777
# ..       ...     ...    ...    ...      ...     ...               ...
# 435        1       3  29703  12051    16027   13135               182
# 436        1       3  39228   1431      764    4510                93
# 437        2       3  14531  15488    30243     437             14841
# 438        1       3  10290   1981     2232    1038               168
# 439        1       3   2787   1698     2510      65               477
#
#      Delicassen
# 0          1338
# 1          1776
# 2          7844
# 3          1788
# 4          5185
# ..          ...
# ...

# %%
df["Channel"].unique()
# Out:
# array([2, 1], dtype=int64)

# %%
df.drop(["Region","Channel"],axis=1,inplace=True)

# %%
df.head(3)
df.shape
# Out:
# (440, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Channel           440 non-null    int64
#  1   Fresh             440 non-null    int64
#  2   Milk              440 non-null    int64
#  3   Grocery           440 non-null    int64
#  4   Frozen            440 non-null    int64
#  5   Detergents_Paper  440 non-null    int64
#  6   Delicassen        440 non-null    int64
# dtypes: int64(7)
# memory usage: 24.2 KB

# %%
df.describe()
# Out:
#           Channel          Fresh          Milk       Grocery        Frozen  \
# count  440.000000     440.000000    440.000000    440.000000    440.000000
# mean     1.322727   12000.297727   5796.265909   7951.277273   3071.931818
# std      0.468052   12647.328865   7380.377175   9503.162829   4854.673333
# min      1.000000       3.000000     55.000000      3.000000     25.000000
# 25%      1.000000    3127.750000   1533.000000   2153.000000    742.250000
# 50%      1.000000    8504.000000   3627.000000   4755.500000   1526.000000
# 75%      2.000000   16933.750000   7190.250000  10655.750000   3554.250000
# max      2.000000  112151.000000  73498.000000  92780.000000  60869.000000
#
#        Detergents_Paper    Delicassen
# count        440.000000    440.000000
# mean        2881.493182   1524.870455
# std         4767.854448   2820.105937
# min            3.000000      3.000000
# 25%          256.750000    408.250000
# 50%          816.500000    965.500000
# ...

# %%
df.isnull().sum()
# Out:
# Channel             0
# Fresh               0
# Milk                0
# Grocery             0
# Frozen              0
# Detergents_Paper    0
# Delicassen          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=df)
plt.title('Boxplot of the data')
plt.show()

# %%
for i in df.keys():
    q25, q75 = np.percentile(df[i], [25,75])
    iqr = q75 - q25
    
    lower_bound = q25 - iqr*1.5
    upper_bound = q75 + iqr*1.5
    
    df.loc[df[i] < lower_bound, i] = lower_bound
    df.loc[df[i] > upper_bound, i] = upper_bound
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_8348\1335195531.py:8: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-0.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[df[i] < lower_bound, i] = lower_bound
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_8348\1335195531.py:8: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-17581.25' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[df[i] < lower_bound, i] = lower_bound
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_8348\1335195531.py:8: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '-6952.875' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[df[i] < lower_bound, i] = lower_bound
# ...

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=df)
plt.title('Boxplot of the data')
plt.show()

# %%
df.describe()
# Out:
#           Channel         Fresh          Milk      Grocery       Frozen  \
# count  440.000000    440.000000    440.000000    440.00000   440.000000
# mean     1.322727  11357.568182   5048.592045   7236.37500  2507.085795
# std      0.468052  10211.542235   4386.377073   6596.53308  2408.297738
# min      1.000000      3.000000     55.000000      3.00000    25.000000
# 25%      1.000000   3127.750000   1533.000000   2153.00000   742.250000
# 50%      1.000000   8504.000000   3627.000000   4755.50000  1526.000000
# 75%      2.000000  16933.750000   7190.250000  10655.75000  3554.250000
# max      2.000000  37642.750000  15676.125000  23409.87500  7772.250000
#
#        Detergents_Paper   Delicassen
# count        440.000000   440.000000
# mean        2392.616477  1266.715341
# std         2940.794090  1083.069792
# min            3.000000     3.000000
# 25%          256.750000   408.250000
# 50%          816.500000   965.500000
# 75%         3922.000000  1820.250000
# ...

# %%
for i in df.columns:
    plt.figure(figsize=[8,6])
    sns.displot(df[i])
    plt.title(i)
    plt.show()

# %%
df.drop(["Channel"],axis=1,inplace=True)

# %%
df2 = np.sqrt(df)

# %%
plt.figure(figsize=(10,5))
sns.histplot(df, kde=True)  # Before transformation
plt.title("Before Transformation")
plt.show()

plt.figure(figsize=(10,5))
sns.histplot(df2, kde=True)  # After transformation
plt.title("After Transformation")
plt.show()

# %%
df2.hist(figsize=(20,10),bins=30, color='lightblue', edgecolor='black')
plt.show()

# %%
sns.pairplot(df2)

# %% [markdown]
# ### Heatmap

# %%
corr=df2.corr()
plt.figure(figsize=(10,5))
plt.title('Pearson Correlation Matrix',fontsize=15)
sns.heatmap(corr, center=0.5,annot=True)
plt.xticks(rotation=0)
plt.yticks(rotation=0)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.regplot(x="Milk",y="Grocery",data=df2,color="red")
# Out:
# <Axes: xlabel='Milk', ylabel='Grocery'>

# %%
plt.figure(figsize=(8,5))
sns.regplot(x="Grocery",y="Detergents_Paper",data=df2,color="green")
# Out:
# <Axes: xlabel='Grocery', ylabel='Detergents_Paper'>

# %% [markdown]
# # PCA

# %%
from sklearn.preprocessing import StandardScaler

# Step 2: Standardize the data (to make it suitable for PCA)
scaler = StandardScaler()
df2= scaler.fit_transform(df2)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)  # Reduce to 2 principal components
df2 = pca.fit_transform(df2)

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

kmeans = KMeans(n_clusters=5, random_state=42)
clusters = kmeans.fit_predict(df2)

# Add clusters to a DataFrame
df_pca_clusters = pd.DataFrame(df2, columns=['PC1', 'PC2'])
df_pca_clusters["Cluster"] = clusters

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x=df_pca_clusters["PC1"], y=df_pca_clusters["PC2"], hue=df_pca_clusters["Cluster"], palette="viridis", s=50)

# Plot cluster centroids
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c="red", marker="X", s=200, label="Centroids")

plt.title("K-Means Clustering after PCA")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.legend()
plt.show()

# %%
explained_variance = pca.explained_variance_ratio_
print(f"Explained Variance: {explained_variance * 100}")
print(f"Total Variance Captured: {np.sum(explained_variance) * 100:.2f}%")
# Out:
# Explained Variance: [42.34793904 29.75241971]
# Total Variance Captured: 72.10%

# %% [markdown]
# ## Elbow Method

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
sse=[]
k_range=range(1,11)
for k in k_range:
    kmeans=KMeans(n_clusters=k,random_state=42)
    kmeans.fit(df2)
    sse.append(kmeans.inertia_)

plt.plot(k_range,sse,marker="o")
plt.xlabel("Number of clusters")
plt.ylabel("Sum of squared distances (SSE)")
plt.title("Elbow Method for optimal K")
plt.show()

# %%
import pandas as pd

if isinstance(df2, np.ndarray):
    df2 = pd.DataFrame(df2)  # Convert to DataFrame

kmeans=KMeans(n_clusters=4,random_state=42)
df2["Cluster"]=kmeans.fit_predict(df2)

# %%
df2
# Out:
#          Fresh       Milk    Grocery    Frozen  Detergents_Paper  Delicassen  \
# 0    10.609272   9.912868   9.324913  3.824753          7.191018    6.048031
# 1     9.165476   9.952158   9.890205  6.478903          7.575267    6.491734
# 2     8.927805   9.687670   9.362608  7.002914          7.700381    7.921836
# 3    10.731905   5.880751   8.060349  8.945669          4.745172    6.502672
# 4    12.263068   8.576287   9.210919  7.910118          6.492648    7.921836
# ..         ...        ...        ...       ...               ...         ...
# 435  13.128046  10.477454  11.251568  9.389375          3.672974    6.851772
# 436  13.929013   6.150493   5.257428  8.194909          3.105423    6.959564
# 437  10.979280  11.155752  12.369432  4.572149          9.851702    6.573340
# 438  10.071725   6.671464   6.873431  5.676091          3.600206    6.789530
# 439   7.265813   6.419252   7.078128  2.839412          4.673364    2.685350
#
#      Cluster
# 0          0
# 1          0
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Scatter plot with cluster colors
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df2.iloc[:, 0], y=df2.iloc[:, 1], hue=df2["Cluster"], palette="viridis", s=50)

plt.title("K-Means Clustering")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.legend(title="Cluster")
plt.show()

# %% [markdown]
# ### Evaluation

# %%
df2.columns
# Out:
# Index(['Fresh', 'Milk', 'Grocery', 'Frozen', 'Detergents_Paper', 'Delicassen',
#        'Cluster'],
#       dtype='object')

# %%
features=df2[['Fresh', 'Milk', 'Grocery', 'Frozen', 'Detergents_Paper', 'Delicassen']]
print(silhouette_score(features,df2["Cluster"]))
# Out:
# 0.21808244161017964
