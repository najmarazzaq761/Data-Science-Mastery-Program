# %% [markdown]
# ## Question :1

# %%
attendence_list=["john","Emma","Eva","sophia","Emma"]
print(attendence_list)
# Out:
# ['john', 'Emma', 'Eva', 'sophia', 'Emma']

# %%
print("The number of present  students are ",len(attendence_list))
# Out:
# The number of students are  5

# %% [markdown]
# ## Question :2

# %%
attendence_set=set(attendence_list)
print(attendence_set)
# Out:
# {'sophia', 'Eva', 'Emma', 'john'}

# %%
print("The total  number of unique students  present are ",len(attendence_set))
# Out:
# The total  number of unique students  present are  4

# %% [markdown]
# ## Question :3

# %%
attendence_tuple=("John","Emma","Ava","Sophia")
print(attendence_tuple)
# Out:
# ('John', 'Emma', 'Ava', 'Sophia')

# %% [markdown]
# ## Question :4

# %%
attendence_dict={"John":1,"Emma":2,"Ava":1,"Sophia":1}
print(attendence_dict)
# Out:
# {'John': 1, 'Emma': 2, 'Ava': 1, 'Sophia': 1}
